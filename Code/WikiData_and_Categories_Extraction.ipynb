# %%
# !pip install autoscraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting autoscraper
#   Downloading autoscraper-1.1.14-py3-none-any.whl (10 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from autoscraper) (4.2.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autoscraper) (2.23.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from autoscraper) (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->autoscraper) (4.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autoscraper) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autoscraper) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autoscraper) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autoscraper) (3.0.4)
# Installing collected packages: autoscraper
# Successfully installed autoscraper-1.1.14

# %%
import pandas as pd
import numpy as np
from autoscraper import AutoScraper

# %%
data = pd.read_csv("Fish_names.csv")

# %%
scraper = AutoScraper()
scraper.load('scrapper2')

# %%
fishData = []
for idx in data.index[17000:]:
    print(idx)
    fish = {}
    fish['ID'] = data['ID'][idx]
    fish['Species Name'] = species = data['Species Name'][idx]
    url = 'https://en.wikipedia.org/wiki/{}'.format(species.replace(' ','_'))
    resultDict = scraper.get_result_similar(url,group_by_alias=True)
    fish.update(resultDict)
    print(fish['wikidata'])
    fishData.append(fish)
    print('----')
# Out:
# 0
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 1
# {'wikidata': ['Wikidata: Q133980'], 'Author': ['Rainboth, 1991'], 'Author Link': [], 'categories': ['Category:IUCN Red List critically endangered species', 'Category:Leuciscinae', 'Category:Freshwater fish of Southeast Asia', 'Category:Fish described in 1991', 'Category:Leuciscinae stubs']}
# ['Wikidata: Q133980']
# ----
# 2
# {'wikidata': ['Wikidata: Q14023599', 'Wikidata: Q115865'], 'Author': ['(Trewavas, 1935)'], 'Author Link': ['/wiki/Ethelwynn_Trewavas'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Haplochromini', 'Category:Monotypic ray-finned fish genera', 'Category:Fish of Lake Malawi', 'Category:Fish described in 1935', 'Category:Cichlid genera']}
# ['Wikidata: Q14023599', 'Wikidata: Q115865']
# ----
# 3
# {'wikidata': ['Wikidata: Q2168067'], 'Author': ['Matsuura & Yoshino, 2004'], 'Author Link': [], 'categories': ['Category:Balistidae', 'Category:Taxa named by Keiichi Matsuura', 'Category:Taxa named by Tetsuo Yoshino', 'Category:Fish described in 2004', 'Category:Triggerfish stubs']}
# ['Wikidata: Q2168067']
# ----
# 4
# {'wikidata': ['Wikidata: Q2327953'], 'Author': ['(Anonymous in Lacépède, 1798)'], 'Author Link': ['/wiki/Bernard_Germain_de_Lac%C3%A9p%C3%A8de'], 'categories': ['Category:Balistidae', 'Category:Fish described in 1798', 'Category:Triggerfish stubs']}
# ['Wikidata: Q2327953']
# ----
# 5
# {'wikidata': ['Wikidata: Q2365198'], 'Author': ['V. H. Nguyễn, 2001'], 'Author Link': [], 'categories': ['Category:IUCN Red List data deficient species', 'Category:Abbottina', 'Category:Fish described in 2001', 'Category:Endemic fauna of Vietnam', 'Category:Cyprinidae stubs']}
# ['Wikidata: Q2365198']
# ----
# 6
# {'wikidata': ['Wikidata: Q2098972'], 'Author': ['Huang & Li, 1995'], 'Author Link': [], 'categories': ['Category:Abbottina', 'Category:Fish described in 1995', 'Category:Cyprinidae stubs']}
# ['Wikidata: Q2098972']
# ----
# 7
# {'wikidata': ['Wikidata: Q2622987'], 'Author': ['K. J. Qin, 1987'], 'Author Link': [], 'categories': ['Category:Abbottina', 'Category:Fish described in 1987', 'Category:Fish of Asia', 'Category:Freshwater fish of China', 'Category:Cyprinidae stubs']}
# ['Wikidata: Q2622987']
# ----
# 8
# {'wikidata': ['Wikidata: Q3111879'], 'Author': ['(H. W. Wu & Ki. Fu. Wang, 1931)'], 'Author Link': [], 'categories': ['Category:Abbottina', 'Category:Fish described in 1931', 'Category:Fish of Asia', 'Category:Freshwater fish of China', 'Category:Cyprinidae stubs']}
# ['Wikidata: Q3111879']
# ----
# 9
# {'wikidata': ['Wikidata: Q581263'], 'Author': ['(Basilewsky, 1855)'], 'Author Link': [], 'categories': ['Category:Abbottina', 'Category:Fish described in 1855', 'Category:Cyprinidae stubs']}
# ['Wikidata: Q581263']
# ----
# 10
# {'wikidata': ['Wikidata: Q2721301'], 'Author': ['(Peters, 1855)'], 'Author Link': [], 'categories': ['Category:IUCN Red List data deficient species', 'Category:Ablabys', 'Category:Fish described in 1855', 'Category:Taxa named by Wilhelm Peters']}
# ['Wikidata: Q2721301']
# ----
# 11
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 12
# {'wikidata': ['Wikidata: Q2523145'], 'Author': ['(Bleeker, 1852)[1]'], 'Author Link': ['/wiki/Pieter_Bleeker'], 'categories': ['Category:Ablabys', 'Category:Fish described in 1852', 'Category:Taxa named by Pieter Bleeker', 'Category:Fish of the Pacific Ocean', 'Category:Fish of the Indian Ocean']}
# ['Wikidata: Q2523145']
# ----
# 13
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 14
# {'wikidata': ['Wikidata: Q2131058', 'Wikidata: Q107053390'], 'Author': ['(G. Cuvier, 1829) [1]'], 'Author Link': ['/wiki/Georges_Cuvier'], 'categories': ['Category:Ablabys', 'Category:Fish of Palau', 'Category:Fish described in 1829', 'Category:Taxa named by Georges Cuvier', 'Category:Venomous fish']}
# ['Wikidata: Q2131058', 'Wikidata: Q107053390']
# ----
# 15
# {'wikidata': ['Wikidata: Q2530772'], 'Author': ['Valenciennes, 1846'], 'Author Link': ['/wiki/Achille_Valenciennes'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Belonidae', 'Category:Pantropical fish', 'Category:Fish described in 1846']}
# ['Wikidata: Q2530772']
# ----
# 16
# {'wikidata': ['Wikidata: Q9138321'], 'Author': ['D. S. Jordan & Starks, 1895'], 'Author Link': ['/wiki/David_Starr_Jordan'], 'categories': ['Category:IUCN Red List data deficient species', 'Category:Gobiidae', 'Category:Fish described in 1895', 'Category:Gobiidae stubs']}
# ['Wikidata: Q9138321']
# ----
# 17
# {'wikidata': ['Wikidata: Q17393862'], 'Author': ['Arunachalam, Raja, Malaiammal & Mayden, 2014 [1]'], 'Author Link': [], 'categories': ['Category:Nemacheilidae', 'Category:Fish of Asia', 'Category:Freshwater fish of India', 'Category:Taxa named by Muthukumarasamy Arunachalam', 'Category:Taxa named by Manickam Raja', 'Category:Taxa named by Punniyam Malaiammal', 'Category:Taxa named by Richard L. Mayden', 'Category:Fish described in 2014', 'Category:Nemacheilidae stubs']}
# ['Wikidata: Q17393862']
# ----
# 18
# {'wikidata': ['Wikidata: Q6418466'], 'Author': ['Hora, 1921'], 'Author Link': ['/wiki/Sunder_Lal_Hora'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Nemacheilidae', 'Category:Freshwater fish of India', 'Category:Taxa named by Sunder Lal Hora', 'Category:Fish described in 1921', 'Category:Nemacheilidae stubs']}
# ['Wikidata: Q6418466']
# ----
# 19
# {'wikidata': ['Wikidata: Q5452041'], 'Author': ['Hora, 1925'], 'Author Link': ['/wiki/Sunder_Lal_Hora'], 'categories': ['Category:Nemacheilidae', 'Category:Fish of Asia', 'Category:Freshwater fish of India', 'Category:Taxa named by Sunder Lal Hora', 'Category:Fish described in 1925', 'Category:Nemacheilidae stubs']}
# ['Wikidata: Q5452041']
# ----
# 20
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 21
# {'wikidata': ['Wikidata: Q5619627'], 'Author': ['N. Sen, 2009'], 'Author Link': [], 'categories': ['Category:Nemacheilidae', 'Category:Fish of Asia', 'Category:Freshwater fish of India', 'Category:Taxa named by Nibedita Sen (scientist)', 'Category:Fish described in 2009', 'Category:Nemacheilidae stubs']}
# ['Wikidata: Q5619627']
# ----
# 22
# {'wikidata': ['Wikidata: Q1034061'], 'Author': ['Barman, 1985'], 'Author Link': [], 'categories': ['Category:IUCN Red List vulnerable species', 'Category:Nemacheilidae', 'Category:Freshwater fish of India', 'Category:Taxa named by Ram Prasad Barman', 'Category:Fish described in 1985', 'Category:Nemacheilidae stubs']}
# ['Wikidata: Q1034061']
# ----
# 23
# {'wikidata': ['Wikidata: Q21777831'], 'Author': ['Arunachalam, Raja, Malaiammal & Mayden, 2014'], 'Author Link': [], 'categories': ['Category:Nemacheilidae', 'Category:Fish of Asia', 'Category:Freshwater fish of India', 'Category:Taxa named by Muthukumarasamy Arunachalam', 'Category:Taxa named by Manickam Raja', 'Category:Taxa named by Punniyam Malaiammal', 'Category:Taxa named by Richard L. Mayden', 'Category:Fish described in 2014', 'Category:Nemacheilidae stubs']}
# ['Wikidata: Q21777831']
# ----
# 24
# {'wikidata': ['Wikidata: Q21365813'], 'Author': ['Kosygin, 2012'], 'Author Link': [], 'categories': ['Category:Nemacheilidae', 'Category:Fish of Asia', 'Category:Freshwater fish of India', 'Category:Taxa named by Laishram Kosygin', 'Category:Fish described in 2012', 'Category:Nemacheilidae stubs']}
# ['Wikidata: Q21365813']
# ----
# 25
# {'wikidata': ['Wikidata: Q144534'], 'Author': ['(Linnaeus, 1758)'], 'Author Link': ['/wiki/Carl_Linnaeus'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Abramis', 'Category:Freshwater fish of Europe', 'Category:Fish of Europe', 'Category:Fish of the Caspian Sea', 'Category:Fish described in 1758', 'Category:Taxa named by Carl Linnaeus']}
# ['Wikidata: Q144534']
# ----
# 26
# {'wikidata': ['Wikidata: Q3767571'], 'Author': ['(Steindachner, 1878)'], 'Author Link': ['/wiki/Franz_Steindachner'], 'categories': ['Category:Anostomidae', 'Category:Freshwater fish of Colombia', 'Category:Magdalena River', 'Category:Taxa named by Franz Steindachner', 'Category:Fish described in 1878']}
# ['Wikidata: Q3767571']
# ----
# 27
# {'wikidata': ['Wikidata: Q896607', 'Wikidata: Q109531834'], 'Author': ['(Günther, 1868)'], 'Author Link': ['/wiki/Albert_G%C3%BCnther'], 'categories': ['Category:Anostomidae', 'Category:Fish described in 1868', 'Category:Taxa named by Albert Günther']}
# ['Wikidata: Q896607', 'Wikidata: Q109531834']
# ----
# 28
# {'wikidata': ['Wikidata: Q481523', 'Wikidata: Q106409975'], 'Author': ['(Quoy & Gaimard, 1825)'], 'Author Link': ['/wiki/Jean_Ren%C3%A9_Constant_Quoy'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Abudefduf', 'Category:Endemic fauna of Hawaii', 'Category:Fish of Hawaii', 'Category:Fish described in 1825', 'Category:Taxa named by Jean René Constant Quoy', 'Category:Taxa named by Joseph Paul Gaimard', 'Category:Pomacentridae stubs']}
# ['Wikidata: Q481523', 'Wikidata: Q106409975']
# ----
# 29
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 30
# {'wikidata': ['Wikidata: Q2162265', 'Wikidata: Q107327127'], 'Author': ['(Gill, 1862)'], 'Author Link': ['/wiki/Theodore_Gill'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Abudefduf', 'Category:Fish of Mexican Pacific coast', 'Category:Western Central American coastal fauna', 'Category:Galápagos Islands coastal fauna', 'Category:Fish described in 1862', 'Category:Pomacentridae stubs']}
# ['Wikidata: Q2162265', 'Wikidata: Q107327127']
# ----
# 31
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 32
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 33
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 34
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 35
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 36
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 37
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 38
# {'wikidata': ['Wikidata: Q3512634'], 'Author': ['(Day, 1870)[2]'], 'Author Link': ['/wiki/Francis_Day'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Abudefduf', 'Category:Fish of the Indian Ocean', 'Category:Marine fauna of East Africa', 'Category:Fish described in 1870']}
# ['Wikidata: Q3512634']
# ----
# 39
# {'wikidata': ['Wikidata: Q2070648', 'Wikidata: Q106414213'], 'Author': ['(Linnaeus, 1758)'], 'Author Link': ['/wiki/Carl_Linnaeus'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Abudefduf', 'Category:Fish of the Atlantic Ocean', 'Category:Fish described in 1758', 'Category:Taxa named by Carl Linnaeus']}
# ['Wikidata: Q2070648', 'Wikidata: Q106414213']
# ----
# 40
# {'wikidata': ['Wikidata: Q2302511'], 'Author': ['Cuvier, 1830'], 'Author Link': ['/wiki/Georges_Cuvier'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Abudefduf', 'Category:Marine fish of Southern Australia', 'Category:Fish described in 1830', 'Category:Taxa named by Georges Cuvier']}
# ['Wikidata: Q2302511']
# ----
# 41
# {'wikidata': ['Wikidata: Q962972', 'Wikidata: Q106407600'], 'Author': ['Lacépède, 1801'], 'Author Link': ['/wiki/Bernard_Germain_de_Lac%C3%A9p%C3%A8de'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Abudefduf', 'Category:Marine fish of Northern Australia', 'Category:Taxa named by Bernard Germain de Lacépède', 'Category:Fish described in 1801']}
# ['Wikidata: Q962972', 'Wikidata: Q106407600']
# ----
# 42
# {'wikidata': ['Wikidata: Q2402954'], 'Author': ['(Forsskål, 1775)'], 'Author Link': [], 'categories': ['Category:Abudefduf', 'Category:Animals described in 1775', 'Category:Pomacentridae stubs']}
# ['Wikidata: Q2402954']
# ----
# 43
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 44
# {'wikidata': ['Wikidata: Q3762208', 'Wikidata: Q106410401'], 'Author': ['(Müller & Troschel, 1848)'], 'Author Link': [], 'categories': ['Category:Taxa named by Johannes Peter Müller', 'Category:Taxa named by Franz Hermann Troschel', 'Category:Abudefduf', 'Category:Pomacentridae stubs']}
# ['Wikidata: Q3762208', 'Wikidata: Q106410401']
# ----
# 45
# {'wikidata': ['Wikidata: Q1826598'], 'Author': ['(Gill, 1862)'], 'Author Link': ['/wiki/Theodore_Gill'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Abudefduf', 'Category:Fish of the Gulf of California', 'Category:Fish of Mexican Pacific coast', 'Category:Western Central American coastal fauna']}
# ['Wikidata: Q1826598']
# ----
# 46
# {'wikidata': ['Wikidata: Q2217479', 'Wikidata: Q106410411'], 'Author': ['(Quoy & Gaimard, 1825)'], 'Author Link': ['/wiki/Jean_Ren%C3%A9_Constant_Quoy'], 'categories': ['Category:IUCN Red List least concern species', 'Category:IUCN Red List vulnerable species', 'Category:Abudefduf', 'Category:Marine fish of Northern Australia', 'Category:Fish described in 1825']}
# ['Wikidata: Q2217479', 'Wikidata: Q106410411']
# ----
# 47
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 48
# {'wikidata': ['Wikidata: Q2647392'], 'Author': ['Merrett & J. A. Moore, 2005'], 'Author Link': ['/wiki/Nigel_Merrett'], 'categories': ['Category:Stephanoberycidae', 'Category:Monotypic ray-finned fish genera', 'Category:Taxa named by Nigel Merrett', 'Category:Ray-finned fish stubs']}
# ['Wikidata: Q2647392']
# ----
# 49
# {'wikidata': ['Wikidata: Q310910'], 'Author': ['J. G. Nielsen, 1977[2]'], 'Author Link': [], 'categories': ['Category:IUCN Red List least concern species', 'Category:Ophidiidae', 'Category:Deep sea fish', 'Category:Fish of the Atlantic Ocean', 'Category:Fish of the Indian Ocean', 'Category:Fish of the Pacific Ocean', 'Category:Fish described in 1977', 'Category:Taxa named by Jørgen G. Nielsen']}
# ['Wikidata: Q310910']
# ----
# 50
# {'wikidata': ['Wikidata: Q5556676'], 'Author': ['Taliev, 1955[1]'], 'Author Link': ['/wiki/Dmitrii_Nikolaevich_Taliev'], 'categories': ['Category:Abyssocottidae', 'Category:Fish described in 1955', 'Category:Taxa named by Dmitrii Nikolaevich Taliev', 'Category:Scorpaeniformes stubs']}
# ['Wikidata: Q5556676']
# ----
# 51
# {'wikidata': ['Wikidata: Q5430759'], 'Author': ['Berg, 1906[1]'], 'Author Link': [], 'categories': ['Category:Abyssocottidae', 'Category:Fish described in 1906', 'Category:Scorpaeniformes stubs']}
# ['Wikidata: Q5430759']
# ----
# 52
# {'wikidata': ['Wikidata: Q5625392'], 'Author': ['Berg, 1906.[1]'], 'Author Link': ['/wiki/Lev_Berg'], 'categories': ['Category:Abyssocottidae', 'Category:Fish described in 1906', 'Category:Scorpaeniformes stubs']}
# ['Wikidata: Q5625392']
# ----
# 53
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 54
# {'wikidata': ['Wikidata: Q651293'], 'Author': ['Quoy & Gaimard, 1824'], 'Author Link': ['/wiki/Jean_Ren%C3%A9_Constant_Quoy'], 'categories': ['Category:Fish described in 1824', 'Category:Tetraodontiformes stubs']}
# ['Wikidata: Q651293']
# ----
# 55
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 56
# {'wikidata': ['Wikidata: Q3270238'], 'Author': ['Holleman & Buxton, 1993'], 'Author Link': [], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthanectes', 'Category:Fish described in 1993', 'Category:Blenniiformes stubs']}
# ['Wikidata: Q3270238']
# ----
# 57
# {'wikidata': ['Wikidata: Q1816843'], 'Author': ['Holleman & Buxton, 1993'], 'Author Link': [], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthanectes', 'Category:Fish described in 1993', 'Category:Blenniiformes stubs']}
# ['Wikidata: Q1816843']
# ----
# 58
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 59
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 60
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 61
# {'wikidata': [], 'Author': [], 'Author Link': [], 'categories': []}
# []
# ----
# 62
# {'wikidata': ['Wikidata: Q526228'], 'Author': ['(S. F. Baird, 1855)'], 'Author Link': ['/wiki/Spencer_Fullerton_Baird'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Lepominae', 'Category:Fish described in 1855', 'Category:Freshwater fish of the Southeastern United States', 'Category:Taxa named by Spencer Fullerton Baird', 'Category:Freshwater fish of North America']}
# ['Wikidata: Q526228']
# ----
# 63
# {'wikidata': ['Wikidata: Q2254123'], 'Author': ['(Longley, 1927)'], 'Author Link': ['/wiki/William_Harding_Longley'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Fish of the Caribbean', 'Category:Taxa named by William Harding Longley', 'Category:Fish described in 1927', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2254123']
# ----
# 64
# {'wikidata': ['Wikidata: Q2185772'], 'Author': ['Hastings & D. R. Robertson, 1999'], 'Author Link': [], 'categories': ['Category:IUCN Red List vulnerable species', 'Category:Acanthemblemaria', 'Category:Fish of Costa Rica', 'Category:Fish described in 1999', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2185772']
# ----
# 65
# {'wikidata': ['Wikidata: Q2472067'], 'Author': ['Brock, 1940'], 'Author Link': [], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Fish of the Gulf of California', 'Category:Fish of Mexican Pacific coast', 'Category:Fish described in 1940', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2472067']
# ----
# 66
# {'wikidata': ['Wikidata: Q2231908'], 'Author': ['Smith-Vaniz & Palacio, 1974'], 'Author Link': [], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Fish of Panama', 'Category:Fish of Colombia', 'Category:Fish described in 1974', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2231908']
# ----
# 67
# {'wikidata': ['Wikidata: Q2427576'], 'Author': ['J. S. Stephens & Hobson, 1966'], 'Author Link': [], 'categories': ['Category:IUCN Red List vulnerable species', 'Category:Acanthemblemaria', 'Category:Endemic fauna of the Galápagos Islands', 'Category:Galápagos Islands coastal fauna', 'Category:Fish described in 1966', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2427576']
# ----
# 68
# {'wikidata': ['Wikidata: Q1816436'], 'Author': ['J. E. Böhlke, 1957'], 'Author Link': ['/wiki/James_Erwin_B%C3%B6hlke'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Fauna of the Bahamas', 'Category:Fish of Cuba', 'Category:Fish of the Caribbean', 'Category:Fish of the Dominican Republic', 'Category:Fish described in 1957', 'Category:Taxa named by James Erwin Böhlke', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q1816436']
# ----
# 69
# {'wikidata': ['Wikidata: Q2653570'], 'Author': ['Beebe & Tee-Van, 1938'], 'Author Link': ['/wiki/William_Beebe'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Fish of the Gulf of California', 'Category:Fish described in 1938', 'Category:Taxa named by William Beebe', 'Category:Taxa named by John Tee-Van', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2653570']
# ----
# 70
# {'wikidata': ['Wikidata: Q3312371'], 'Author': ['J. S. Stephens, 1963'], 'Author Link': [], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Western Central American coastal fauna', 'Category:Fish of Costa Rica', 'Category:Fish of Panama', 'Category:Fish of Colombia', 'Category:Fish of Ecuador', 'Category:Fish described in 1963', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q3312371']
# ----
# 71
# {'wikidata': ['Wikidata: Q2303517'], 'Author': ['Smith-Vaniz & Palacio, 1974'], 'Author Link': [], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Fish of Honduras', 'Category:Fish of the Caribbean', 'Category:Fish described in 1974', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2303517']
# ----
# 72
# {'wikidata': ['Wikidata: Q2116445'], 'Author': ['G. S. Myers & Reid, 1936'], 'Author Link': ['/wiki/George_S._Myers'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Western Central American coastal fauna', 'Category:Fish of Costa Rica', 'Category:Fish of Panama', 'Category:Fish described in 1936', 'Category:Taxa named by Earl Desmond Reid', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2116445']
# ----
# 73
# {'wikidata': ['Wikidata: Q2439594'], 'Author': ['J. T. Williams, 2002'], 'Author Link': ['/wiki/Jeffrey_T._Williams'], 'categories': ['Category:IUCN Red List data deficient species', 'Category:Acanthemblemaria', 'Category:Fish described in 2002', 'Category:Fish of the Caribbean', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2439594']
# ----
# 74
# {'wikidata': ['Wikidata: Q6418496'], 'Author': ['H. C. Lin & Galland, 2010'], 'Author Link': [], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Fish of the Gulf of California', 'Category:Fish of Mexican Pacific coast', 'Category:Fish described in 2010', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q6418496']
# ----
# 75
# {'wikidata': ['Wikidata: Q2137345'], 'Author': ['Almany & C. C. Baldwin, 1996'], 'Author Link': [], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Fish of Trinidad and Tobago', 'Category:Fish described in 1996', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2137345']
# ----
# 76
# {'wikidata': ['Wikidata: Q2487086'], 'Author': ['Brock, 1940'], 'Author Link': [], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Fish of the Gulf of California', 'Category:Fish of Mexican Pacific coast', 'Category:Fish described in 1940', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2487086']
# ----
# 77
# {'wikidata': ['Wikidata: Q2617956'], 'Author': ['Hastings & D. R. Robertson, 1999'], 'Author Link': [], 'categories': ['Category:IUCN Red List vulnerable species', 'Category:Acanthemblemaria', 'Category:Fish of Mexican Pacific coast', 'Category:Fish described in 1999', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2617956']
# ----
# 78
# {'wikidata': ['Wikidata: Q2429612'], 'Author': ['J. E. Böhlke, 1961[2]'], 'Author Link': ['/wiki/James_Erwin_B%C3%B6hlke'], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Fish of the Caribbean', 'Category:Fish described in 1961', 'Category:Taxa named by James Erwin Böhlke']}
# ['Wikidata: Q2429612']
# ----
# 79
# {'wikidata': ['Wikidata: Q1984034'], 'Author': ['Smith-Vaniz & Palacio, 1974'], 'Author Link': [], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Fish of the Lesser Antilles', 'Category:Fish described in 1974', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q1984034']
# ----
# 80
# {'wikidata': ['Wikidata: Q2357622'], 'Author': ['G. D. Johnson & Brothers, 1989'], 'Author Link': [], 'categories': ['Category:IUCN Red List data deficient species', 'Category:Acanthemblemaria', 'Category:Vertebrates of Belize', 'Category:Fish described in 1989', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2357622']
# ----
# 81
# {'wikidata': ['Wikidata: Q2149939'], 'Author': ['J. S. Stephens, 1970'], 'Author Link': [], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Fish of Costa Rica', 'Category:Fish of Colombia', 'Category:Fish described in 1970', 'Category:Chaenopsidae stubs']}
# ['Wikidata: Q2149939']
# ----
# 82
# {'wikidata': ['Wikidata: Q2204176'], 'Author': ['Metzelaar, 1919'], 'Author Link': [], 'categories': ['Category:IUCN Red List least concern species', 'Category:Acanthemblemaria', 'Category:Fishkeeping', 'Category:Fish of the Caribbean', 'Category:Taxa named by Jan Marie Metzelaar', 'Category:Fish described in 1919']}
# ['Wikidata: Q2204176']
# ----
# 83
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-8755cdcf759b> in <module>()
#       6     fish['Species Name'] = species = data['Species Name'][idx]
#       7     url = 'https://en.wikipedia.org/wiki/{}'.format(species.replace(' ','_'))
# ----> 8     resultDict = scraper.get_result_similar(url,group_by_alias=True)
#       9     print(resultDict)
#      10     fish.update(resultDict)
#
# /usr/local/lib/python3.7/dist-packages/autoscraper/auto_scraper.py in get_result_similar(self, url, html, soup, request_args, grouped, group_by_alias, unique, attr_fuzz_ratio, keep_blank, keep_order, contain_sibling_leaves)
#     540             keep_blank=keep_blank,
#     541             keep_order=keep_order,
# --> 542             contain_sibling_leaves=contain_sibling_leaves,
#     543         )
#     544
#
# /usr/local/lib/python3.7/dist-packages/autoscraper/auto_scraper.py in _get_result_by_func(self, func, url, html, soup, request_args, grouped, group_by_alias, unique, attr_fuzz_ratio, **kwargs)
#     416     ):
#     417         if not soup:
# --> 418             soup = self._get_soup(url=url, html=html, request_args=request_args)
#     419
#     420         keep_order = kwargs.get("keep_order", False)
#
# /usr/local/lib/python3.7/dist-packages/autoscraper/auto_scraper.py in _get_soup(cls, url, html, request_args)
#     117             return BeautifulSoup(html, "lxml")
#     118
# --> 119         html = cls._fetch_html(url, request_args)
#     120         html = normalize(unescape(html))
#     121
#
# /usr/local/lib/python3.7/dist-packages/autoscraper/auto_scraper.py in _fetch_html(cls, url, request_args)
#     103         user_headers = request_args.pop("headers", {})
#     104         headers.update(user_headers)
# --> 105         res = requests.get(url, headers=headers, **request_args)
#     106         if res.encoding == "ISO-8859-1" and not "ISO-8859-1" in res.headers.get(
#     107             "Content-Type", ""
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connection.py in connect(self)
#     299     def connect(self):
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#     303
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:

# %%
fishDF = pd.DataFrame.from_dict(fishData)

# %%
fishDF.to_csv('fishWiki.csv', index = False)
fishDF.to_pickle('fishWiki.pkl')
